# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sn

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train = X_train / 255
X_test = X_test /255

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2726 - accuracy: 0.9226
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1245 - accuracy: 0.9630
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0862 - accuracy: 0.9742
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0662 - accuracy: 0.9803
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0529 - accuracy: 0.9840
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0423 - accuracy: 0.9867
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0349 - accuracy: 0.9885
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0282 - accuracy: 0.9911
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0226 - accuracy: 0.9933
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0193 - accuracy: 0.9942

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.2647 - accuracy: 0.9263
# [0.2646595239639282, 0.9262999892234802]

# %%
plt.matshow(X_test[0])

# %%
y_predicted = model.predict(X_test)
y_predicted = model.predict(X_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
y_predicted_labels[0]
# Out:
# 313/313 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 7

# %%
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
